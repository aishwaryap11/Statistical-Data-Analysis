# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student-mat.csv', sep=';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
summary = df.describe()
print(summary)
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
duplicate_columns = df.columns[df.columns.duplicated()]
if len(duplicate_columns) == 0:
    print("No duplicate columns found.")
else:
    print("Duplicate columns found:", duplicate_columns)
# Out:
# No duplicate columns found.

# %%
df.shape
# Out:
# (395, 33)

# %%
# Grouping data by 'Medu' and 'Fedu' calculating the average for each category
age_by_sex = df.groupby('Medu')['Fedu'].mean().reset_index()

# Creating a bar plot
plt.figure(figsize=(8, 6))
plt.bar(age_by_sex['Medu'], age_by_sex['Fedu'], color=['green', 'purple'])
plt.xlabel('Medu')
plt.ylabel('Fedu')
plt.show()

# %%
avg_age_by_parents_edu = avg_age_by_parents_edu.sort_values(by='Avg_Parents_Edu')

# Line plot
plt.figure(figsize=(8, 6))
plt.plot(avg_age_by_parents_edu['Avg_Parents_Edu'], avg_age_by_parents_edu['age'], marker='o', linestyle='-', color='red')
plt.xlabel('Average Parents\' Education')
plt.ylabel('Average Age')
plt.title('Line graph: Average Age vs. Average Parents\' Education')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 avg_age_by_parents_edu = avg_age_by_parents_edu.sort_values(by='Avg_Parents_Edu')
#       3 # Line plot
#       4 plt.figure(figsize=(8, 6))
#
# NameError: name 'avg_age_by_parents_edu' is not defined

# %%
df['Parental_Job'] = df.apply(lambda x: x['Mjob'] if x['Mjob'] != x['Fjob'] else 'other', axis=1)

# Count the occurrences of each parental job situation
parental_job_counts = df['Parental_Job'].value_counts(normalize=True) * 100

# Plotting the proportions using a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=parental_job_counts.index, y=parental_job_counts.values, palette='viridis')
plt.title('Proportion of Students by Parental Job Situation')
plt.xlabel('Parental Job Situation')
plt.ylabel('Proportion (%)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Pie charts of Family support and parents cohabitation status

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
Family_support = df['famsup'].value_counts()
cohabitation_counts = df['Pstatus'].value_counts()

# Custom labels for each category
cohabitation_labels = ['Living Apart', 'Living Together']
family_support_labels = ['No Support', 'Family Support']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.pie(cohabitation_counts, labels=cohabitation_labels, autopct='%1.1f%%', colors=['lightskyblue', 'Purple'])
plt.title('Parental Cohabitation Status')

plt.subplot(1, 2, 2)
plt.pie(Family_support, labels=family_support_labels, autopct='%1.1f%%', colors=['lightskyblue', 'Purple'])
plt.title('Family Support')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Layered Histogram - Distribution of overall math scores by parent work status.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

custom_palette = ['skyblue', 'salmon']  # Replace with your desired colors

plt.figure(figsize=(12, 6))
for i, status in enumerate(df['Pstatus'].unique()):
    sns.kdeplot(df[df['Pstatus'] == status]['G3'], label=f'Parent Cohabitation: {status}', shade=True, color=custom_palette[i])

plt.title('Distribution of Math Scores by Parent Cohabitation Status')
plt.xlabel('Math Score (G3)')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_17560\3451890606.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Pstatus'] == status]['G3'], label=f'Parent Cohabitation: {status}', shade=True, color=custom_palette[i])
# C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_17560\3451890606.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Pstatus'] == status]['G3'], label=f'Parent Cohabitation: {status}', shade=True, color=custom_palette[i])

# %% [markdown]
# #### Correlation Matrix Heatmap - Alcohol consumption and health score of students impact grades.

# %%
# change the columns
correlation_matrix = df[['famrel', 'freetime', 'goout', 'G3']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='cividis', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### - Here we can see, going out ang G3 has string negative correlation and free time and going out has positive correlation (obvious)

# %% [markdown]
# #### Box and Whisker Plot - Relationship with family and math score.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='famrel', y='G3', data=df, palette='Blues')
plt.title('Relationship with Family and Math Score')
plt.xlabel('Family Relationship Quality')
plt.ylabel('Math Score (G3)')
plt.show()

# %% [markdown]
# ### An independent two-sample z-test to examine if there is a significant difference in the mean of student grades between two groups ("Parents living together" and "Parents living apart")

# %%
from statsmodels.stats.weightstats import ztest

group1 = df[df['Pstatus'] == 'T']['G3']  # Parents living together
group2 = df[df['Pstatus'] == 'A']['G3']  # Parents living apart

statistic, p_value = ztest(group1, x2=group2, value=0)

mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)
std_dev_group1 = np.std(group1)
std_dev_group2 = np.std(group2)
# Calculate the confidence interval
ci_low, ci_high = (mean_group1 - mean_group2) - 1.96 * np.sqrt(std_dev_group1**2/len(group1) + std_dev_group2**2/len(group2)), \
                  (mean_group1 - mean_group2) + 1.96 * np.sqrt(std_dev_group1**2/len(group1) + std_dev_group2**2/len(group2))

# Print results
print(f"P-value for Family Support: {p_value}")
print(f"Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
print(f"Mean (Family Support: yes): {mean_group1:.2f}")
print(f"Mean (Family Support: no): {mean_group2:.2f}")
print(f"Standard Deviation (Family Support: yes): {std_dev_group1:.2f}")
print(f"Standard Deviation (Family Support: no): {std_dev_group2:.2f}")
# Out:
# P-value for Family Support: 0.24935267942874995
# Confidence Interval: (-2.25, 0.51)
# Mean (Family Support: yes): 10.32
# Mean (Family Support: no): 11.20
# Standard Deviation (Family Support: yes): 4.60
# Standard Deviation (Family Support: no): 4.24

# %% [markdown]
# ### An independent two-sample z-test to examine if there is a significant difference in the mean of student grades between two groups ("With family support" and "Without family support")

# %%
# Import necessary libraries
from statsmodels.stats.weightstats import ztest

# Assume df is your DataFrame with the relevant data
group1 = df[df['famsup'] == 'yes']['G3']  # Family support: yes
group2 = df[df['famsup'] == 'no']['G3']   # Family support: no

# Perform the two-tailed z-test
statistic, p_value = ztest(group1, x2=group2, value=0)

mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)
std_dev_group1 = np.std(group1)
std_dev_group2 = np.std(group2)
# Calculate the confidence interval
ci_low, ci_high = (mean_group1 - mean_group2) - 1.96 * np.sqrt(std_dev_group1**2/len(group1) + std_dev_group2**2/len(group2)), \
                  (mean_group1 - mean_group2) + 1.96 * np.sqrt(std_dev_group1**2/len(group1) + std_dev_group2**2/len(group2))

# Print results
print(f"P-value for Family Support: {p_value}")
print(f"Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
print(f"Mean (Family Support: yes): {mean_group1:.2f}")
print(f"Mean (Family Support: no): {mean_group2:.2f}")
print(f"Standard Deviation (Family Support: yes): {std_dev_group1:.2f}")
print(f"Standard Deviation (Family Support: no): {std_dev_group2:.2f}")
# Out:
# P-value for Family Support: 0.43724375817853167
# Confidence Interval: (-1.30, 0.56)
# Mean (Family Support: yes): 10.27
# Mean (Family Support: no): 10.64
# Standard Deviation (Family Support: yes): 4.54
# Standard Deviation (Family Support: no): 4.62

# %% [markdown]
# #### Same hypothesis with chi-sq test

# %%
from scipy.stats import chi2_contingency

# Assume df is your DataFrame with the relevant data
contingency_table = pd.crosstab(df['Pstatus'], df['G3'])

# Perform the chi-square test
statistic, p_value, _, _ = chi2_contingency(contingency_table)

# Check the p-value
print(f"P-value: {p_value}")

# Compare the p-value to the significance level (e.g., 0.05) to make a decision
# Out:
# P-value: 0.5048919671452796
